# %%
# !nvidia-smi
# Out:
# Sat Sep  6 05:53:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/drive/MyDrive/polyp_detection.v4i.yolov8/train/images/polyp-1-_jpg.rf.13075873ffe616d45bf1eea8a90a2193.jpg'
# Out:
# ...
# Ultralytics 8.3.194 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/polyp_detection.v4i.yolov8/train/images/polyp-1-_jpg.rf.13075873ffe616d45bf1eea8a90a2193.jpg: 640x640 1 fire hydrant, 7.8ms
# Speed: 5.8ms preprocess, 7.8ms inference, 241.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=../content/drive/MyDrive/polyp_detection.v4i.yolov8/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.194 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
# Display the results image generated by the training process
# The path is usually in runs/detect/train/results.png
Image(filename='/content/runs/detect/train/results.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/confusion_matrix_normalized.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/confusion_matrix.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/BoxF1_curve.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/BoxPR_curve.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/BoxP_curve.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/BoxR_curve.png', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/labels.jpg', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/train_batch0.jpg', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch0_labels.jpg', width=1000)

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch1_pred.jpg', width=1000)
